# %%
import pandas as pd

# %%
a1=pd.read_csv("UnOfficial_5182022094107AM.CSV")

# %%
a1.columns=a1.columns.str.lower().str.strip().str.replace(" ",'_')

# %%
a1['votes']=a1.votes.str.replace(",",'').astype(float)

# %%
a1.groupby(['county_name','candidate_name']).votes.sum().unstack().to_clipboard()

# %%
a1
# Out:
#              election_name county_name            office_name district_name  \
# 0    2022 General Election       ADAMS  United States Senator     Statewide
# 1    2022 General Election       ADAMS  United States Senator     Statewide
# 2    2022 General Election       ADAMS  United States Senator     Statewide
# 3    2022 General Election       ADAMS  United States Senator     Statewide
# 4    2022 General Election       ADAMS  United States Senator     Statewide
# ..                     ...         ...                    ...           ...
# 464  2022 General Election        YORK  United States Senator     Statewide
# 465  2022 General Election        YORK  United States Senator     Statewide
# 466  2022 General Election        YORK  United States Senator     Statewide
# 467  2022 General Election        YORK  United States Senator     Statewide
# 468  2022 General Election        YORK  United States Senator     Statewide
#
# ...
