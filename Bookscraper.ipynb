# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
books = []
for i in range(1,51):
    url = f"https://books.toscrape.com/catalogue/page-{i}.html"
    response = requests.get(url)
    response=response.content
    soup = BeautifulSoup(response,'html')
    ol = soup.find('ol')
    articles = ol.find_all('article', class_='product_pod')


    for article in articles:
        image = article.find('img')
        title = image.attrs['alt']
        star = article.find('p')
        star = star['class'][1]
        price = article.find("p",class_='price_color').text
        price = float(price[1:])
        books.append([title,star,price])

# %%
df = pd.DataFrame(books)
df.columns=['title','star_rating','price']

# %%
url = 'https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States'
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'}
r = requests.get(url=url, headers=headers)
soup = BeautifulSoup(r.content,'html')
caption = soup.find('caption')
table = caption.parent
rows=table.find_all('tr')
for row in rows[2:]:
    src = row.th.span.img['src']
    part = src.split('.svg')[0]
    cleaned = part.replace("thumb/",'')
    stripped = cleaned.strip('//')
    img = 'https://{}.svg'.format(stripped)
    filename = img.split('/')[-1]
    flag = requests.get(img, headers=headers)
    if flag.status_code!=200:
        print('error getting {}'.format(filename))
    else:
        with open(filename, 'wb') as f:
            noop = f.write(flag.content)
            print("save {}".format(filename))

# %%
url = 'http://booklooks.org/book-reports-a-1'
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'}
r = requests.get(url=url, headers=headers)
soup = BeautifulSoup(r.content,'html')

# %%
caption = soup.find_all("td")

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html class="ko_Theme" lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="A busy parent's quick reference to objectionable material your child or young adult may be reading." name="description"/><meta content="" name="keywords"/><title>Book Reports - A — Book Looks</title>
# <link href="https://fonts.googleapis.com" rel="preconnect"/><link href="https://fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://fonts.gstatic.com" rel="dns-prefetch"/>
# <link href="https://cdnjs.cloudflare.com" rel="preconnect"/><link href="https://cdnjs.cloudflare.com" rel="dns-prefetch"/>
# <link href="https://cdn.jsdelivr.net" rel="preconnect"/><link href="https://cdn.jsdelivr.net" rel="dns-prefetch"/>
# <base href="/"/>
# <!--Default JS/CSS Location is //booklooks.org//-->
# <link href="index.php?rss=blog" rel="alternate" title="Blog" type="application/rss+xml"/>
# <link href="data/files/booklookslogo_1648811212.jpg" rel="shortcut icon"/>
# <link href="data/files/booklookslogo_1648811212.jpg" rel="apple-touch-icon"/>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.4.0/jquery.min.js" type="text/javascript"></script>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@4.4.1/dist/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="//booklooks.org//inc/live.css?ver=4_0_0_beta_19" rel="stylesheet" type="text/css"/>
# <!--Google Fonts-->
# <link href="//fonts.googleapis.com/css?family=Montserrat:200,400,700|Raleway:200,400,700&amp;subset=latin-ext&amp;display=swap" rel="stylesheet" type="text/css"/>
# <!--The Open Graph-->
# <meta content="data/files/6fdc0f2d6ec5f8fe9eb7f515e72026ee2.jpg" property="og:image"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries --><!--[if lt IE 9]><script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script><script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script><![endif]--><style>	body{/*visibility:hidden;*/overflow:hidden}	body#body{visibility:visible;overflow:auto}	#websiteLoading .spinner{width:120px;height:120px;	  margin: -60px 0 0 -60px;}	#websiteLoading .path {	  stroke: var(--color1_75);	}	.spinnerHolder{position:relative;height:50px;display:none}	.spinnerHolder.active{display:block}	#websiteLoading{visibility:visible;position:fixed;top:0;left:0;right:0;bottom:0;transition:0.5s all;z-index:100;background: linear-gradient(-105deg, rgba(255,255,255,0.8), rgba(255,255,255,.95));}	#websiteLoading::after {		content:"";		background: #fff;		height: 150px;		width: 150px;		border:1px solid rgba(0,0,0,0.2);		border-radius:100%;		box-shadow: 5px 5px 400px rgba(0,0,0,0.5);		position: absolute;		top: 50%;		left: 50%;		margin: -65px 0 0 -65px;		width: 130px;		height: 130px;	}	</style>
# <style>:root{--kopageColor_Accent: #179BD7;--kopageColor_Accent_75: rgba(23,155,215,0.7);--kopageColor_Accent_50: rgba(23,155,215,0.5);--kopageColor_Accent_25: rgba(23,155,215,0.25);--kopageColor_AccentLight: rgba(23,155,215,0.1);--kopageColor_stripesAccent:repeating-linear-gradient(
# 	  -45deg,#005f9b,#179BD7 20px,#005f9b 20px,#005f9b 50px,#179BD7 50px,#179BD7 65px);--kopageColor_LeftMenu:#293A4A}</style><style>
#
# 	.ko_Theme .topmenu a:hover, .ko_Theme .topmenu .active a {
# 	    background:inherit;
# 	}
# 	.ko_Theme .menuHolder li a {
# 		margin: 0;
# 		padding: 0;
# 		border: 0;
# 		font-size: 100%;
# 		font: inherit;
# 		vertical-align: baseline;
# 		line-height: 1;
# 	    color: inherit;
# 	    text-shadow: none;
# 	}
# 	.ko_Theme .menuHolder li {
# 	    display: inline-block;
# 	    padding:0;
# 	}
# 	.ko_Theme .menuHolder{ flex-flow: row wrap; }
# 	.ko_Theme .menuHolder,.ko_Theme #headerMenu{/*;overflow:auto; --inmodulemenu was not working well-- */padding:0}
# 	/*html:not(.koTheme4) */
# 	.ko_Theme .logoHolder #logoReplacer h2,.ko_Theme .logoHolder a,.ko_Theme .logoHolder {
# 	    line-height:1;padding:0;margin:0;;height:auto;
# 	}
# 	.ko_Theme .logoHolder img{max-height:auto;}
#
# 	/*.ko_Theme #headerMenu { overflow:auto;display:flex;flex-direction: row;justify-content: space-between;align-items: center;}*/
# 	.ko_Theme #headerMenu .container {/*overflow:auto;*/display:flex;flex-direction: row;justify-content: space-between;align-items: center;}
#
#
# :root{--color1:#36413e;--color2:#5d5e60;--color1_rgb: 54,65,62;--color1_hsl: 164,9%,23%;--color1_hs: 164,9%;--color1_h: 164;--color1_s: 9%;--color1_l: 23%;--color1_25:#cdd0cf;--color1_50:#9ba09f;--color1_75:#68716e;--color1_125:#29312f;--color1_150:#1b211f;--color1_175:#0e1010;--color2_rgb: 93,94,96;--color2_hsl: 220,2%,37%;--color2_hs: 220,2%;--color2_h: 220;--color2_s: 2%;--color2_l: 37%;--color2_25:#d7d7d7;--color2_50:#aeafb0;--color2_75:#868688;--color2_125:#464748;--color2_150:#2f2f30;--color2_175:#171818;--color1_bw:rgba(255,255,255,0.8);--color1_25_bw:rgba(0,0,0,0.8);--color1_50_bw:rgba(255,255,255,0.8);--color1_75_bw:rgba(255,255,255,0.8);--color1_125_bw:rgba(255,255,255,0.8);--color1_150_bw:rgba(255,255,255,0.8);--color1_175_bw:rgba(255,255,255,0.8);--color2_bw:rgba(255,255,255,0.8);--color2_25_bw:rgba(0,0,0,0.8);--color2_50_bw:rgba(255,255,255,0.8);--color2_75_bw:rgba(255,255,255,0.8);--color2_125_bw:rgba(255,255,255,0.8);--color2_150_bw:rgba(255,255,255,0.8);--color2_175_bw:rgba(255,255,255,0.8);;--font1:"Montserrat";--font2:"Raleway";--font3:"Helvetica Neue",sans-serif;--color1_rgb: 54,65,62;--color1_hsl: 164,9%,23%;--color1_hs: 164,9%;--color1_h: 164;--color1_s: 9%;--color1_l: 23%;--color1_25:#cdd0cf;--color1_50:#9ba09f;--color1_75:#68716e;--color1_125:#29312f;--color1_150:#1b211f;--color1_175:#0e1010;--color2_rgb: 93,94,96;--color2_hsl: 220,2%,37%;--color2_hs: 220,2%;--color2_h: 220;--color2_s: 2%;--color2_l: 37%;--color2_25:#d7d7d7;--color2_50:#aeafb0;--color2_75:#868688;--color2_125:#464748;--color2_150:#2f2f30;--color2_175:#171818;--color1_bw:rgba(255,255,255,0.8);--color1_25_bw:rgba(0,0,0,0.8);--color1_50_bw:rgba(255,255,255,0.8);--color1_75_bw:rgba(255,255,255,0.8);--color1_125_bw:rgba(255,255,255,0.8);--color1_150_bw:rgba(255,255,255,0.8);--color1_175_bw:rgba(255,255,255,0.8);--color2_bw:rgba(255,255,255,0.8);--color2_25_bw:rgba(0,0,0,0.8);--color2_50_bw:rgba(255,255,255,0.8);--color2_75_bw:rgba(255,255,255,0.8);--color2_125_bw:rgba(255,255,255,0.8);--color2_150_bw:rgba(255,255,255,0.8);--color2_175_bw:rgba(255,255,255,0.8);}#contentArea .koColor {color:#36413e;}ul.koCheckList li:before {background:#36413e;}.ko_Theme #website .btn-primary {background-color:var(--color2_175);border-color:var(--color2_175);}.ko_Theme #website .btn-outline-primary {color:var(--color2_175);border-color:var(--color2_175);}.ko_Theme #website .btn-outline-primary:hover {background-color:var(--color2_175);color:var(--color1_bw);border-color:var(--color2_175);}#website .page-item.active .page-link {background-color:#36413e;color:var(--color1_bw);border-color:var(--color2_175);}#contentArea a:not(.btn),#contentArea a.btn-link {color:var(--color2_175)}#website.kopageMenu a:not(.btn):not(.kopageMenuButton),#website.kopageMenu a.btn-link {color:var(--color2_175)}.ko_Theme #contentArea, .ko_Theme .koThemeDark #contentArea .whiteShadowContainer {color:var(--color2_175)}#contentArea h1, #contentArea h2, #contentArea h3,#contentArea h1 a, #contentArea h2 a, #contentArea h3 a, .koThemeDark #contentArea .whiteShadowContainer strong, .koThemeDark #contentArea .whiteShadowContainer h1, .koThemeDark #contentArea .whiteShadowContainer h2, .koThemeDark #contentArea .whiteShadowContainer h3{color: rgb(0, 0, 0);}#contentArea h4, #contentArea h5, #contentArea h6,#contentArea h4 a, #contentArea h5 a, #contentArea h6 a, .koThemeDark #contentArea .whiteShadowContainer strong, .koThemeDark #contentArea .whiteShadowContainer h4, .koThemeDark #contentArea .whiteShadowContainer h5, .koThemeDark #contentArea .whiteShadowContainer h6 {color: rgb(0, 0, 0);}.ko_Theme #website #footerContent {color: rgba(0, 0, 0, .5);}.ko_Theme #website #footerContent h1,.ko_Theme #website #footerContent h2,.ko_Theme #website #footerContent h3,.ko_Theme #website #footerContent h4,.ko_Theme #website #footerContent h5,.ko_Theme #website #footerContent h6 {color: rgba(0, 0, 0,1);}.ko_Theme #website, .ko_Theme #website p{font-family:var(--font2),sans-serif;}.ko_Theme #website a.btn, ...
# </head><body class=""> <div id="searchHolder">
# <form action="" method="get">
# <div>Search</div>
# <input autocomplete="off" class="form-control" id="searchInput" name="search" type="text"/>
# <button class="btn btn-color1" type="submit"><i class="fas fa-search"></i></button>
# <button class="btn btn-light" onclick="$('#searchHolder').removeClass('active')" type="reset"><i class="fas fa-times"></i></button>
# </form>
# </div>
# <div class="isLoading" id="websiteLoading"><svg class="spinner" viewbox="0 0 50 50"><circle class="path" cx="25" cy="25" fill="none" r="20" stroke-width="5"></circle></svg></div><div class="" id="website"><header id="header"><div id="headerMenu"><div class="container"><div class="logoHolder"><a class="logo" href="/"><h2><img alt="BookLooks.org" id="WebsiteLogo" src="data/files/openbooknew-1.png" style="border:0"/><span>BookLooks.org</span></h2></a></div><ul class="menuHolder topmenu"><li><a href="http://booklooks.org/"><span>Home</span></a></li>
# <li><a href="about"><span>About</span></a></li>
# <li><a href="blog"><span>Blog</span></a></li>
# <li><a href="ratings-system"><span>Ratings System</span></a></li>
# <li><a href="book-reports"><span>Book Reports</span></a></li>
# <li class="accent1"><a href="contact"><span>Contact</span></a></li>
# </ul></div></div></header><main class="WxEditableArea" id="contentArea"><div class="kelement" id="contentAreaElement"></div><section class="kedit keditDark keditTextShadow" data-background="data/files/25f13df5d4dea7a4da3345a357147e97.jpg" data-background-pos="2" data-bgcolor="--color2_175" data-padding="50-50" data-pcid="4007" id="kpg_4173360" style="background: url(data/files/25f13df5d4dea7a4da3345a357147e97.jpg) left top repeat;;background-color:var(--color2_175);padding-top:50px;padding-bottom:50px">
# <div class="container">
# <ol class="breadcrumb"><li class="breadcrumb-item"><a href="http://booklooks.org">Home</a></li><li class="breadcrumb-item active"><span class="keditable">Book Reports - A</span></li></ol>
# <h1 class="keditable">Book Reports - A</h1>
# </div>
# </section><section class="kedit" data-pcid="4016.3" id="kpg_447838" style=""><div class="container table-responsive">
# <table class="table koTable">
# <thead>
# <tr>
# <th class="keditable" scope="col"><a href="book-reports-1">#</a></th>
# <th class="keditable" scope="col"><a href="book-reports-a-1">A</a></th>
# <th class="keditable" scope="col"><a href="book-reports-b">B</a></th><th class="keditable"><a href="book-reports-c">C</a></th><th class="keditable"><a href="book-reports-d">D</a></th><th class="keditable"><a href="book-reports-e">E</a></th><th class="keditable"><a href="book-reports-f">F</a></th><th class="keditable"><a href="book-reports-g">G</a></th><th class="keditable"><a href="book-reports-h">H</a></th><th class="keditable"><a href="book-reports-i">I</a></th><th class="keditable"><a href="book-reports-j">J</a></th><th class="keditable"><a href="book-reports-k">K</a></th><th class="keditable"><a href="book-reports-l">L</a></th><th class="keditable"><a href="book-reports-m">M</a></th><th class="keditable"><a href="book-reports-n">N</a></th><th class="keditable"><a href="book-reports-o">O</a></th><th class="keditable"><a href="book-reports-p">P</a></th><th class="keditable"><a href="book-reports-q">Q</a></th><th class="keditable"><a href="book-reports-r">R</a></th><th class="keditable"><a href="book-reports-s">S</a></th><th class="keditable"><a href="book-reports-t">T</a></th><th class="keditable"><a href="book-reports-u">U</a></th><th class="keditable"><a href="book-reports-v">V</a></th><th class="keditable"><a href="book-reports-w">W</a></th><th class="keditable"><a href="book-reports-x">X</a></th><th class="keditable"><a href="book-reports-y">Y</a></th><th class="keditable"><a href="book-reports-z">Z</a></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# </div></section>
# <section class="kedit" id="kpg_9440541" style=""><div class="container"><h2 class="keditable mb-5">Content Advisory</h2><div class="keditable"><span style="color: rgb(0, 0, 0);">Be advised that there may be explicit material in our book reports that is inappropriate for children. It is only included for completeness so that parents seeking to inform themselves may do so with all the available information needed to make informed decisions.</span></div></div></section><section class="kedit" data-pcid="4016.3" id="kpg_180266" style="">
# <div class="container table-responsive">
# <table class="table koTable">
# <thead>
# <tr>
# <th class="keditable" scope="col">Title</th>
# <th class="keditable" scope="col">Author</th><th class="keditable">Rating       </th><th class="keditable"> Slick Sheet</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/A is for activist.pdf" target="_blank">A is for Activist</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Innosanto Nagara</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/An Abc of equality.pdf" target="_blank">An ABC of Equality</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Chana Ginelle Ewing</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Ablaze With Color.pdf" target="_blank">Ablaze with Color: A Story of Painter Alma Thomas </a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Jeanne Walker Harvey</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part.pdf" target="_blank">The Absolutely True Diary of a Part-Time Indian</a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Sherman Alexie</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Ace Voices.pdf" target="_blank">Ace Voices</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Eris Young</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Ada twist scientist.pdf" target="_blank">Ada Twist, Scientist</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Andrea Beaty</td><td class="keditable">0</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Adjustment day.pdf" target="_blank">Adjustment Day</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Chuck Palahniuk</td><td class="keditable">4</td><td class="keditable"><a href="data/files/Book Looks Reports/A/Adjustment Day slick sheet.pdf" target="_blank">here</a></td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Advocate for Yourself.pdf" target="_blank">Advocating for Yourself</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Abby Colich</td><td class="keditable">0</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/After.pdf" target="_blank">After</a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Amy Efaw</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Al Capone does my shirts.pdf" target="_blank">Al Capone Does My Shirts</a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Gennifer Choldenko</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/All American Boys.pdf" target="_blank">All American Boys</a></td><td class="keditable">Jason Reynolds and Brendan Kiely</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/All Because You Matter.pdf" target="_blank">All Because You Matter</a></td><td class="keditable">Tami Charles</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/All Boys Arent Blue.pdf" target="_blank">All Boys Aren't Blue</a></td><td class="keditable">George M. Johnson</td><td class="keditable">4</td><td class="keditable"><a href="data/files/Book Looks Reports/A/All Boys Arent Blue Slick Sheet.pdf" target="_blank">here</a></td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/All The Bright Places.pdf" target="_blank">All the Bright Places</a></td><td class="keditable">Jennifer Niven</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/All the Things we do in the dark.pdf" target="_blank">All the Things We Do in the Dark</a></td><td class="keditable">Saundra Mitchell</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/All Your Perfects.pdf" target="_blank">All Your Perfects</a></td><td class="keditable">Colleen Hoover</td><td class="keditable">4</td><td class="keditable"><a href="data/files/Book Looks Reports/A/All your perfects slick sheet.pdf" target="_blank">here</a></td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank">Allegedly</a></td><td class="keditable">Tiffany Jackson</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Alma and How she got her name.pdf" target="_blank">Alma and How She Got Her Name</a></td><td class="keditable">Juana Martinez-Neal</td><td class="keditable">0</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Almost perfect.pdf" target="_blank">Almost Perfect</a></td><td class="keditable">Brian Katcher</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Alt Ed.pdf" target="_blank">Alt Ed</a></td><td class="keditable">Catherine Atkins</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/America.pdf" target="_blank">America</a></td><td class="keditable">E.R. Frank</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/An Ordinary Day.pdf" target="_blank">An Ordinary Day</a></td><td class="keditable">Elana K. Arnold</td><td class="keditable">0</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Anatomy of a Boyfriend.pdf" target="_blank">Anatomy of a Boyfriend</a></td><td class="keditable">Daria Snadowsky</td><td class="keditable">4</td><td class="keditable"><a href="data/files/Book Looks Reports/A/Anatomy of a Boyfriend slick sheet.pdf" target="_blank">here</a></td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Anatomy of a single Girl.pdf" target="_blank">Anatomy of a Single Girl</a></td><td class="keditable">Daria Snadowsky</td><td class="keditable">4</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/And they lived.pdf" target="_blank">And They Lived...</a></td><td class="keditable">Steven Salvatore</td><td class="keditable">4</td><td class="keditable"><a href="data/files/Book Looks Reports/A/And They Lived slick sheet.pdf" target="_blank">here</a></td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/ANGUS THONGS AND FULL FRONTAL SNOGGING CONFESSIONS OF GEORGIA NICOLSON.pdf" target="_blank">ANGUS, THONGS, AND FULL-FRONTAL SNOGGING</a></td><td class="keditable">Louise Rennison</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Anne Franks Diary graphic novel.pdf" target="_blank">Anne Frank's Diary: The Graphic Adaptation</a></td><td class="keditable">Ari Folman and David Polonsky</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Antiracist baby.pdf" target="_blank">Antiracist Baby</a></td><td class="keditable">Ibram X. Kendi</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Antonios card.pdf" target="_blank">Antonio's Card</a></td><td class="keditable">Rigoberto Gonzalez</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Are you a boy or are you a girl.pdf" target="_blank">Are You a Boy or Are You a Girl?</a></td><td class="keditable">Sarah Savage and Fox Fisher</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Are You a Butterfly.pdf" target="_blank">Are You a Butterfly?</a></td><td class="keditable">Judy Allen and Tudor Humphries</td><td class="keditable">0</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Are you an ant.pdf" target="_blank">Are You an Ant?</a></td><td class="keditable">Judy Allen and Tudor Humphries</td><td class="keditable">0</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Are you my Mother A Comic Drama.pdf" target="_blank">Are You My Mother: A Comic Drama</a></td><td class="keditable">Alison Bechdel</td><td class="keditable">4</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Art of Drag.pdf" target="_blank">The Art of Drag</a><a href="data/files/Book Looks Reports/A/Are you my Mother A Comic Drama.pdf" target="_blank"><br/></a></td><td class="keditable">Jake Hall</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Art of Racing in the RAin.pdf" target="_blank">The Art of Racing in the Rain</a><a href="data/files/Book Looks Reports/A/Are you my Mother A Comic Drama.pdf" target="_blank"><br/></a></td><td class="keditable">Garth Stein</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Ask the Passengers.pdf" target="_blank">Ask the Passengers</a></td><td class="keditable">A.S. King</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Assassin and the Desert.pdf" target="_blank">The Assassin and the Desert</a></td><td class="keditable">Sarah J. Maas</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Assassin and the Empire.pdf" target="_blank">The Assassin and the Empire</a></td><td class="keditable">Sarah J. Maas</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Assassin and the Pirate Lord.pdf" target="_blank">The Assassin and the Pirate Lord</a></td><td class="keditable">Sarah J. Maas</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank">The Assassin's Blade</a></td><td class="keditable">Sarah J. Maas</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom.pdf" target="_blank">Assassination Classroom Volume 1</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom Volume 2.pdf" target="_blank">Assassination Classroom Volume 2</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination classroom volume 3.pdf" target="_blank">Assassination Classroom Volume 3</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom volume 4.pdf" target="_blank">Assassination Classroom Volume 4</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom Volume 5.pdf" target="_blank">Assassination Classroom Volume 5</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom volume 6.pdf" target="_blank">Assassination Classroom Volume 6</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom volume 7.pdf" target="_blank">Assassination Classroom Volume 7</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom Volume 11.pdf" target="_blank">Assassination Classroom Volume 11</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Attack of the Black Rectangles.pdf" target="_blank">Attack of the Black Rectangles</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Amy Sarig King</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Autoboyography.pdf" target="_blank">Autoboyography</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Christina Lauren</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr>
# </tbody>
# </table>
# </div>
# </section></main><footer id="footerContent"><section class="kedit keditFooter keditFooter2 p-0 keditDark kfilter1" data-background="data/files/n4pu0b.jpg" data-background-pos="1" data-bgcolor="--color1_75" data-pcid="5500.3" id="kedit_g743fvhm6" style="background: url(data/files/n4pu0b.jpg) no-repeat 50% 0px;background-size:cover;;background-color:var(--color1_75)"><div class="container keditFooterLine1">
# <div class="row">
# <div class="col-lg-8 d-flex flex-column align-self-center">
# <div class="kedit flex-fill" id="kpg_2371661" style=""><div class="keditable">Sign up for the BookLooks.org newsletter and have new book reports delivered right to your inbox<div><br/></div></div></div>
# </div>
# <div class="col-lg-4 align-self-center">
# <div class="kedit flex-fill" id="kpg_7585332" style=""><div class="keditable keditable-auto"><div id="custom-substack-embed"><style>.csw-theme-custom{
#             --csw-primary-color:#FFFFFF;
#             --csw-input-color:#000000;
#             --csw-text-color:#000000;
#             --csw-input-text-color:#FFFFFF;
#             }</style><form class="custom-substack-widget csw-theme-custom"><input placeholder="example@gmail.com" value=""/><button type="submit">Subscribe</button></form></div>
# <script>
#   window.CustomSubstackWidget = {
#     substackUrl: "booklooks.substack.com",
#     theme: "custom",
#     colors: {
#       primary: "#FFFFFF",
#       input: "#000000",
#       email: "#FFFFFF",
#       text: "#000000",
#     }
#   };
# </script>
# <script async="" src="https://substackapi.com/widget.js"></script>
# </div></div>
# </div>
# </div>
# </div>
# <div class="keditFooterLine2 keditFooterLineDarker">
# <div class="container text-center">
# <div class="kedit" id="kpg_4287473" style=""><div class="keditable keditFooterCopyright"><div><span style="font-family: var(--font2),sans-serif; font-size: 1.1rem; letter-spacing: -0.02em;">Copyright ©2022 BookLooks.org LLC, All Rights Reserved</span><br/></div></div></div>
# <div class="pt-0 kedit keditFooterApp" id="kpg_5528154" style=""><div class="footerHolder" id="keditFooterModule"><div class="social_fa social_bw social_bwh social_footer"><a href="http://twitter.com/@BookLooksOrg" target="_blank"><i class="fab fa-twitter fa-2x fa-fw"></i></a></div></div></div>
# </div>
# </div>
# <div class="keditLayer_header h-auto" data-color="var(--color1_175)" data-height="h-auto" data-style="6" style="fill:var(--color1_175);transform: scale(1,-1)"><svg height="100%" preserveaspectratio="none" viewbox="0 0 3112 100" width="100%">
# <defs></defs>
# <g transform="matrix(0.997611, 0, 0, 0.941303, -0.999626, -451.432556)">
# <g transform="matrix(1.05523,0,0,0.197876,-141.168,242.24)">
# <path d="M3091.86,1204.82C2087.93,1828.86 1103.28,1781.18 133.779,1204.82L133.779,1741.7L3091.86,1741.7L3091.86,1204.82Z" style="fill-rule:nonzero;"></path>
# </g>
# </g>
# </svg></div></section></footer></div><a href="javascript:void(null)" id="scrollToTop"><i class="fa fa-fw fa-arrow-up"></i></a>
# <script>
#
# 		window.onload =  function(){$('#websiteLoading').fadeOut(function(){$(this).remove()});$('body').attr('id','body');$(document).keyup(function(e){
#
# 				 // Escape and Control (ESC+CTRL) pressed, show login screen
# 			 	 if ((e.ctrlKey || e.metaKey) && (e.keyCode == 27/* || e.keyCode == 10*/)) {
# 					 window.location.href="index.php?open=login";
# 				 }
#
#
# 			});
#
#
# 		};
#
# 		</script><script>var magnificPopupInit=function(){$('a.lightbox').magnificPopup({type:'image',gallery:{enabled:true}});}</script><link href="https://cdnjs.cloudflare.com/ajax/libs/magnific-popup.js/1.1.0/magnific-popup.css" rel="stylesheet"/><script async="" onload="magnificPopupInit()" src="https://cdnjs.cloudflare.com/ajax/libs/magnific-popup.js/1.1.0/jquery.magnific-popup.js"></script>
# <script type="text/javascript"></script>
# <script defer="" src="https://cdn.jsdelivr.net/npm/instant.page@3.0.0/instantpage.min.js" type="module"></script><script>var menuCaption = "Select a page";</script><script async="" src="//booklooks.org//inc/live.js?" type="text/javascript"></script><link href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.12.0/css/all.min.css" rel="stylesheet"/><script src="https://cdn.jsdelivr.net/npm/bootstrap@4.4.1/dist/js/bootstrap.bundle.min.js" type="text/javascript"></script>
# <!-- AOS (Animate on Scroll) -->
# <link href="https://cdn.jsdelivr.net/npm/aos@2.3.4/dist/aos.css" rel="stylesheet"/>
# <script defer="" src="https://cdn.jsdelivr.net/npm/aos@2.3.4/dist/aos.min.js"></script><script>$(function(){AOS.init({offset:20,duration:800,easing:'ease',anchorPlacement:'top-top'});})</script><script>$(function(e){
# 		var a = 400,s = e('#scrollToTop');
# 		e(window).scroll(function(){
# 		e(this).scrollTop() > a ? s.addClass('active') : s.removeClass('active')}), s.on('click', function(a) {s.removeClass('active');e('body,html').animate({scrollTop: 0})
# 	})})</script><script type="text/javascript">$(function(){var dataText="supermode=stats&page=/book-reports-a-1&referrer=";$.ajax({type: "POST",url: "index.php",data: dataText,success: function(data) {}});});</script><script id="jsMenusSetup" type="text/javascript">window.addEventListener('load',function(){ddlevelsmenu.setup("1", "topbar","0","0");});</script>
# </body></html>>

# %%
caption
# Out:
# [<td class="keditable"><a href="data/files/Book Looks Reports/A/A is for activist.pdf" target="_blank">A is for Activist</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Innosanto Nagara</td>,
#  <td class="keditable">1</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/An Abc of equality.pdf" target="_blank">An ABC of Equality</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Chana Ginelle Ewing</td>,
#  <td class="keditable">1</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Ablaze With Color.pdf" target="_blank">Ablaze with Color: A Story of Painter Alma Thomas </a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Jeanne Walker Harvey</td>,
#  <td class="keditable">1</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part.pdf" target="_blank">The Absolutely True Diary of a Part-Time Indian</a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Sherman Alexie</td>,
#  <td class="keditable">2</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Ace Voices.pdf" target="_blank">Ace Voices</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Eris Young</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Ada twist scientist.pdf" target="_blank">Ada Twist, Scientist</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Andrea Beaty</td>,
#  <td class="keditable">0</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Adjustment day.pdf" target="_blank">Adjustment Day</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Chuck Palahniuk</td>,
#  <td class="keditable">4</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Adjustment Day slick sheet.pdf" target="_blank">here</a></td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Advocate for Yourself.pdf" target="_blank">Advocating for Yourself</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Abby Colich</td>,
#  <td class="keditable">0</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/After.pdf" target="_blank">After</a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Amy Efaw</td>,
#  <td class="keditable">2</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Al Capone does my shirts.pdf" target="_blank">Al Capone Does My Shirts</a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Gennifer Choldenko</td>,
#  <td class="keditable">2</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/All American Boys.pdf" target="_blank">All American Boys</a></td>,
#  <td class="keditable">Jason Reynolds and Brendan Kiely</td>,
#  <td class="keditable">2</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/All Because You Matter.pdf" target="_blank">All Because You Matter</a></td>,
#  <td class="keditable">Tami Charles</td>,
#  <td class="keditable">1</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/All Boys Arent Blue.pdf" target="_blank">All Boys Aren't Blue</a></td>,
#  <td class="keditable">George M. Johnson</td>,
#  <td class="keditable">4</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/All Boys Arent Blue Slick Sheet.pdf" target="_blank">here</a></td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/All The Bright Places.pdf" target="_blank">All the Bright Places</a></td>,
#  <td class="keditable">Jennifer Niven</td>,
#  <td class="keditable">2</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/All the Things we do in the dark.pdf" target="_blank">All the Things We Do in the Dark</a></td>,
#  <td class="keditable">Saundra Mitchell</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/All Your Perfects.pdf" target="_blank">All Your Perfects</a></td>,
#  <td class="keditable">Colleen Hoover</td>,
#  <td class="keditable">4</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/All your perfects slick sheet.pdf" target="_blank">here</a></td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank">Allegedly</a></td>,
#  <td class="keditable">Tiffany Jackson</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Alma and How she got her name.pdf" target="_blank">Alma and How She Got Her Name</a></td>,
#  <td class="keditable">Juana Martinez-Neal</td>,
#  <td class="keditable">0</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Almost perfect.pdf" target="_blank">Almost Perfect</a></td>,
#  <td class="keditable">Brian Katcher</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Alt Ed.pdf" target="_blank">Alt Ed</a></td>,
#  <td class="keditable">Catherine Atkins</td>,
#  <td class="keditable">2</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/America.pdf" target="_blank">America</a></td>,
#  <td class="keditable">E.R. Frank</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/An Ordinary Day.pdf" target="_blank">An Ordinary Day</a></td>,
#  <td class="keditable">Elana K. Arnold</td>,
#  <td class="keditable">0</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Anatomy of a Boyfriend.pdf" target="_blank">Anatomy of a Boyfriend</a></td>,
#  <td class="keditable">Daria Snadowsky</td>,
#  <td class="keditable">4</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Anatomy of a Boyfriend slick sheet.pdf" target="_blank">here</a></td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Anatomy of a single Girl.pdf" target="_blank">Anatomy of a Single Girl</a></td>,
#  <td class="keditable">Daria Snadowsky</td>,
#  <td class="keditable">4</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/And they lived.pdf" target="_blank">And They Lived...</a></td>,
#  <td class="keditable">Steven Salvatore</td>,
#  <td class="keditable">4</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/And They Lived slick sheet.pdf" target="_blank">here</a></td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/ANGUS THONGS AND FULL FRONTAL SNOGGING CONFESSIONS OF GEORGIA NICOLSON.pdf" target="_blank">ANGUS, THONGS, AND FULL-FRONTAL SNOGGING</a></td>,
#  <td class="keditable">Louise Rennison</td>,
#  <td class="keditable">2</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Anne Franks Diary graphic novel.pdf" target="_blank">Anne Frank's Diary: The Graphic Adaptation</a></td>,
#  <td class="keditable">Ari Folman and David Polonsky</td>,
#  <td class="keditable">2</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Antiracist baby.pdf" target="_blank">Antiracist Baby</a></td>,
#  <td class="keditable">Ibram X. Kendi</td>,
#  <td class="keditable">1</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Antonios card.pdf" target="_blank">Antonio's Card</a></td>,
#  <td class="keditable">Rigoberto Gonzalez</td>,
#  <td class="keditable">1</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Are you a boy or are you a girl.pdf" target="_blank">Are You a Boy or Are You a Girl?</a></td>,
#  <td class="keditable">Sarah Savage and Fox Fisher</td>,
#  <td class="keditable">1</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Are You a Butterfly.pdf" target="_blank">Are You a Butterfly?</a></td>,
#  <td class="keditable">Judy Allen and Tudor Humphries</td>,
#  <td class="keditable">0</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Are you an ant.pdf" target="_blank">Are You an Ant?</a></td>,
#  <td class="keditable">Judy Allen and Tudor Humphries</td>,
#  <td class="keditable">0</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Are you my Mother A Comic Drama.pdf" target="_blank">Are You My Mother: A Comic Drama</a></td>,
#  <td class="keditable">Alison Bechdel</td>,
#  <td class="keditable">4</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/The Art of Drag.pdf" target="_blank">The Art of Drag</a><a href="data/files/Book Looks Reports/A/Are you my Mother A Comic Drama.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Jake Hall</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/The Art of Racing in the RAin.pdf" target="_blank">The Art of Racing in the Rain</a><a href="data/files/Book Looks Reports/A/Are you my Mother A Comic Drama.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Garth Stein</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Ask the Passengers.pdf" target="_blank">Ask the Passengers</a></td>,
#  <td class="keditable">A.S. King</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/The Assassin and the Desert.pdf" target="_blank">The Assassin and the Desert</a></td>,
#  <td class="keditable">Sarah J. Maas</td>,
#  <td class="keditable">2</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/The Assassin and the Empire.pdf" target="_blank">The Assassin and the Empire</a></td>,
#  <td class="keditable">Sarah J. Maas</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/The Assassin and the Pirate Lord.pdf" target="_blank">The Assassin and the Pirate Lord</a></td>,
#  <td class="keditable">Sarah J. Maas</td>,
#  <td class="keditable">2</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank">The Assassin's Blade</a></td>,
#  <td class="keditable">Sarah J. Maas</td>,
#  <td class="keditable">2</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom.pdf" target="_blank">Assassination Classroom Volume 1</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Yusei Matsui</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom Volume 2.pdf" target="_blank">Assassination Classroom Volume 2</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Yusei Matsui</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination classroom volume 3.pdf" target="_blank">Assassination Classroom Volume 3</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Yusei Matsui</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom volume 4.pdf" target="_blank">Assassination Classroom Volume 4</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Yusei Matsui</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom Volume 5.pdf" target="_blank">Assassination Classroom Volume 5</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Yusei Matsui</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom volume 6.pdf" target="_blank">Assassination Classroom Volume 6</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Yusei Matsui</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom volume 7.pdf" target="_blank">Assassination Classroom Volume 7</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Yusei Matsui</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom Volume 11.pdf" target="_blank">Assassination Classroom Volume 11</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Yusei Matsui</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Attack of the Black Rectangles.pdf" target="_blank">Attack of the Black Rectangles</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Amy Sarig King</td>,
#  <td class="keditable">2</td>,
#  <td class="keditable">...</td>,
#  <td class="keditable"><a href="data/files/Book Looks Reports/A/Autoboyography.pdf" target="_blank">Autoboyography</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td>,
#  <td class="keditable">Christina Lauren</td>,
#  <td class="keditable">3</td>,
#  <td class="keditable">...</td>]

# %%
caption[4].text
# Out:
# 'An ABC of Equality'

# %%
titles=[]
n=0
for x in titles:
    print("step worked")
    x = caption[n].text
    print("step worked")
    titles.append(x)

# %%
title = []
n=0
while n <200:
    string1 = caption[n].text
    n=n+4
    title.append(string1)
author = []
n=1
while n <200:
    string1 = caption[n].text
    n=n+4
    author.append(string1)
rating = []
n=2
while n <200:
    string1 = caption[n].text
    n=n+4
    rating.append(string1)
slick_sheet = []
n=3
while n <200:
    string1 = caption[n].text
    n=n+4
    slick_sheet.append(string1)

# %%
len(title)
# Out:
# 50

# %%
len(author)
# Out:
# 50

# %%
len(rating)
# Out:
# 50

# %%
len(slick_sheet)
# Out:
# 50

# %%
title?

# %%
df=pd.DataFrame(index=[title])

# %%
df.index=len(title)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1011, in DataFrame.__repr__(self)
#    1008     return buf.getvalue()
#    1010 repr_params = fmt.get_dataframe_repr_params()
# -> 1011 return self.to_string(**repr_params)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1174, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1171 from pandas import option_context
#    1173 with option_context("display.max_colwidth", max_colwidth):
# -> 1174     formatter = fmt.DataFrameFormatter(
#    1175         self,
#    1176         columns=columns,
#    1177         col_space=col_space,
#    1178         na_rep=na_rep,
#    1179         formatters=formatters,
#    1180         float_format=float_format,
#    1181         sparsify=sparsify,
#    1182         justify=justify,
#    1183         index_names=index_names,
#    1184         header=header,
#    1185         index=index,
#    1186         min_rows=min_rows,
#    1187         max_rows=max_rows,
#    1188         max_cols=max_cols,
#    1189         show_dimensions=show_dimensions,
#    1190         decimal=decimal,
#    1191     )
#    1192     return fmt.DataFrameRenderer(formatter).to_string(
#    1193         buf=buf,
#    1194         encoding=encoding,
#    1195         line_width=line_width,
#    1196     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:601, in DataFrameFormatter.__init__(self, frame, columns, col_space, header, index, na_rep, formatters, justify, float_format, sparsify, index_names, max_rows, min_rows, max_cols, show_dimensions, decimal, bold_rows, escape)
#     598 self.show_dimensions = show_dimensions
#     600 self.max_cols_fitted = self._calc_max_cols_fitted()
# --> 601 self.max_rows_fitted = self._calc_max_rows_fitted()
#     603 self.tr_frame = self.frame
#     604 self.truncate()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:745, in DataFrameFormatter._calc_max_rows_fitted(self)
#     742 else:
#     743     max_rows = self.max_rows
# --> 745 return self._adjust_max_rows(max_rows)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:756, in DataFrameFormatter._adjust_max_rows(self, max_rows)
#     748 """Adjust max_rows using display logic.
#     749
#     750 See description here:
#    (...)
#     753 GH #37359
#     754 """
#     755 if max_rows:
# --> 756     if (len(self.frame) > max_rows) and self.min_rows:
#     757         # if truncated, set max_rows showed to min_rows
#     758         max_rows = min(self.min_rows, max_rows)
#     759 return max_rows
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1417, in DataFrame.__len__(self)
#    1413 def __len__(self) -> int:
#    1414     """
#    1415     Returns length of info axis, but here we use the index.
#    1416     """
# -> 1417     return len(self.index)
#
# TypeError: object of type 'int' has no len()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1033, in DataFrame._repr_html_(self)
#    1030     max_cols = get_option("display.max_columns")
#    1031     show_dimensions = get_option("display.show_dimensions")
# -> 1033     formatter = fmt.DataFrameFormatter(
#    1034         self,
#    1035         columns=None,
#    1036         col_space=None,
#    1037         na_rep="NaN",
#    1038         formatters=None,
#    1039         float_format=None,
#    1040         sparsify=None,
#    1041         justify=None,
#    1042         index_names=True,
#    1043         header=True,
#    1044         index=True,
#    1045         bold_rows=True,
#    1046         escape=True,
#    1047         max_rows=max_rows,
#    1048         min_rows=min_rows,
#    1049         max_cols=max_cols,
#    1050         show_dimensions=show_dimensions,
#    1051         decimal=".",
#    1052     )
#    1053     return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1054 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:601, in DataFrameFormatter.__init__(self, frame, columns, col_space, header, index, na_rep, formatters, justify, float_format, sparsify, index_names, max_rows, min_rows, max_cols, show_dimensions, decimal, bold_rows, escape)
#     598 self.show_dimensions = show_dimensions
#     600 self.max_cols_fitted = self._calc_max_cols_fitted()
# --> 601 self.max_rows_fitted = self._calc_max_rows_fitted()
#     603 self.tr_frame = self.frame
#     604 self.truncate()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:745, in DataFrameFormatter._calc_max_rows_fitted(self)
#     742 else:
#     743     max_rows = self.max_rows
# --> 745 return self._adjust_max_rows(max_rows)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:756, in DataFrameFormatter._adjust_max_rows(self, max_rows)
#     748 """Adjust max_rows using display logic.
#     749
#     750 See description here:
#    (...)
#     753 GH #37359
#     754 """
#     755 if max_rows:
# --> 756     if (len(self.frame) > max_rows) and self.min_rows:
#     757         # if truncated, set max_rows showed to min_rows
#     758         max_rows = min(self.min_rows, max_rows)
#     759 return max_rows
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1417, in DataFrame.__len__(self)
#    1413 def __len__(self) -> int:
#    1414     """
#    1415     Returns length of info axis, but here we use the index.
#    1416     """
# -> 1417     return len(self.index)
#
# TypeError: object of type 'int' has no len()

# %%
author
# Out:
# ['Innosanto Nagara',
#  'Chana Ginelle Ewing',
#  'Jeanne Walker Harvey',
#  'Sherman Alexie',
#  'Eris Young',
#  'Andrea Beaty',
#  'Chuck Palahniuk',
#  'Abby Colich',
#  'Amy Efaw',
#  'Gennifer Choldenko',
#  'Jason Reynolds and Brendan Kiely',
#  'Tami Charles',
#  'George M. Johnson',
#  'Jennifer Niven',
#  'Saundra Mitchell',
#  'Colleen Hoover',
#  'Tiffany Jackson',
#  'Juana Martinez-Neal',
#  'Brian Katcher',
#  'Catherine Atkins',
#  'E.R. Frank',
#  'Elana K. Arnold',
#  'Daria Snadowsky',
#  'Daria Snadowsky',
#  'Steven\xa0Salvatore',
#  'Louise Rennison',
#  'Ari Folman and David Polonsky',
#  'Ibram X. Kendi',
#  'Rigoberto Gonzalez',
#  'Sarah Savage and Fox Fisher',
#  'Judy Allen and Tudor Humphries',
#  'Judy Allen and Tudor Humphries',
#  'Alison Bechdel',
#  'Jake Hall',
#  'Garth Stein',
#  'A.S. King',
#  'Sarah J. Maas',
#  'Sarah J. Maas',
#  'Sarah J. Maas',
#  'Sarah J. Maas',
#  'Yusei Matsui',
#  'Yusei Matsui',
#  'Yusei Matsui',
#  'Yusei Matsui',
#  'Yusei Matsui',
#  'Yusei Matsui',
#  'Yusei Matsui',
#  'Yusei Matsui',
#  'Amy Sarig King',
#  'Christina Lauren']

# %%
caption[1+4].text
# Out:
# 'Chana Ginelle Ewing'

# %%
url = 'https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States'
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'}
r = requests.get(url=url, headers=headers)
soup = BeautifulSoup(r.content,'html')
caption = soup.find('caption')

# %%
soup.find_all('ol')
# Out:
# [<ol class="breadcrumb"><li class="breadcrumb-item"><a href="http://booklooks.org">Home</a></li><li class="breadcrumb-item active"><span class="keditable">Book Reports - A</span></li></ol>]

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="ko_Theme" lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="A busy parent's quick reference to objectionable material your child or young adult may be reading." name="description"/><meta content="" name="keywords"/><title>Book Reports - A — Book Looks</title>
# <link href="https://fonts.googleapis.com" rel="preconnect"/><link href="https://fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://fonts.gstatic.com" rel="dns-prefetch"/>
# <link href="https://cdnjs.cloudflare.com" rel="preconnect"/><link href="https://cdnjs.cloudflare.com" rel="dns-prefetch"/>
# <link href="https://cdn.jsdelivr.net" rel="preconnect"/><link href="https://cdn.jsdelivr.net" rel="dns-prefetch"/>
# <base href="/"/>
# <!--Default JS/CSS Location is //booklooks.org//-->
# <link href="index.php?rss=blog" rel="alternate" title="Blog" type="application/rss+xml"/>
# <link href="data/files/booklookslogo_1648811212.jpg" rel="shortcut icon"/>
# <link href="data/files/booklookslogo_1648811212.jpg" rel="apple-touch-icon"/>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.4.0/jquery.min.js" type="text/javascript"></script>
# <link href="https://cdn.jsdelivr.net/npm/bootstrap@4.4.1/dist/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="//booklooks.org//inc/live.css?ver=4_0_0_beta_19" rel="stylesheet" type="text/css"/>
# <!--Google Fonts-->
# <link href="//fonts.googleapis.com/css?family=Montserrat:200,400,700|Raleway:200,400,700&amp;subset=latin-ext&amp;display=swap" rel="stylesheet" type="text/css"/>
# <!--The Open Graph-->
# <meta content="data/files/6fdc0f2d6ec5f8fe9eb7f515e72026ee2.jpg" property="og:image"/>
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries --><!--[if lt IE 9]><script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script><script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script><![endif]--><style>	body{/*visibility:hidden;*/overflow:hidden}	body#body{visibility:visible;overflow:auto}	#websiteLoading .spinner{width:120px;height:120px;	  margin: -60px 0 0 -60px;}	#websiteLoading .path {	  stroke: var(--color1_75);	}	.spinnerHolder{position:relative;height:50px;display:none}	.spinnerHolder.active{display:block}	#websiteLoading{visibility:visible;position:fixed;top:0;left:0;right:0;bottom:0;transition:0.5s all;z-index:100;background: linear-gradient(-105deg, rgba(255,255,255,0.8), rgba(255,255,255,.95));}	#websiteLoading::after {		content:"";		background: #fff;		height: 150px;		width: 150px;		border:1px solid rgba(0,0,0,0.2);		border-radius:100%;		box-shadow: 5px 5px 400px rgba(0,0,0,0.5);		position: absolute;		top: 50%;		left: 50%;		margin: -65px 0 0 -65px;		width: 130px;		height: 130px;	}	</style>
# <style>:root{--kopageColor_Accent: #179BD7;--kopageColor_Accent_75: rgba(23,155,215,0.7);--kopageColor_Accent_50: rgba(23,155,215,0.5);--kopageColor_Accent_25: rgba(23,155,215,0.25);--kopageColor_AccentLight: rgba(23,155,215,0.1);--kopageColor_stripesAccent:repeating-linear-gradient(
# 	  -45deg,#005f9b,#179BD7 20px,#005f9b 20px,#005f9b 50px,#179BD7 50px,#179BD7 65px);--kopageColor_LeftMenu:#293A4A}</style><style>
#
# 	.ko_Theme .topmenu a:hover, .ko_Theme .topmenu .active a {
# 	    background:inherit;
# 	}
# 	.ko_Theme .menuHolder li a {
# 		margin: 0;
# 		padding: 0;
# 		border: 0;
# 		font-size: 100%;
# 		font: inherit;
# 		vertical-align: baseline;
# 		line-height: 1;
# 	    color: inherit;
# 	    text-shadow: none;
# 	}
# 	.ko_Theme .menuHolder li {
# 	    display: inline-block;
# 	    padding:0;
# 	}
# 	.ko_Theme .menuHolder{ flex-flow: row wrap; }
# 	.ko_Theme .menuHolder,.ko_Theme #headerMenu{/*;overflow:auto; --inmodulemenu was not working well-- */padding:0}
# 	/*html:not(.koTheme4) */
# 	.ko_Theme .logoHolder #logoReplacer h2,.ko_Theme .logoHolder a,.ko_Theme .logoHolder {
# 	    line-height:1;padding:0;margin:0;;height:auto;
# 	}
# 	.ko_Theme .logoHolder img{max-height:auto;}
#
# 	/*.ko_Theme #headerMenu { overflow:auto;display:flex;flex-direction: row;justify-content: space-between;align-items: center;}*/
# 	.ko_Theme #headerMenu .container {/*overflow:auto;*/display:flex;flex-direction: row;justify-content: space-between;align-items: center;}
#
#
# :root{--color1:#36413e;--color2:#5d5e60;--color1_rgb: 54,65,62;--color1_hsl: 164,9%,23%;--color1_hs: 164,9%;--color1_h: 164;--color1_s: 9%;--color1_l: 23%;--color1_25:#cdd0cf;--color1_50:#9ba09f;--color1_75:#68716e;--color1_125:#29312f;--color1_150:#1b211f;--color1_175:#0e1010;--color2_rgb: 93,94,96;--color2_hsl: 220,2%,37%;--color2_hs: 220,2%;--color2_h: 220;--color2_s: 2%;--color2_l: 37%;--color2_25:#d7d7d7;--color2_50:#aeafb0;--color2_75:#868688;--color2_125:#464748;--color2_150:#2f2f30;--color2_175:#171818;--color1_bw:rgba(255,255,255,0.8);--color1_25_bw:rgba(0,0,0,0.8);--color1_50_bw:rgba(255,255,255,0.8);--color1_75_bw:rgba(255,255,255,0.8);--color1_125_bw:rgba(255,255,255,0.8);--color1_150_bw:rgba(255,255,255,0.8);--color1_175_bw:rgba(255,255,255,0.8);--color2_bw:rgba(255,255,255,0.8);--color2_25_bw:rgba(0,0,0,0.8);--color2_50_bw:rgba(255,255,255,0.8);--color2_75_bw:rgba(255,255,255,0.8);--color2_125_bw:rgba(255,255,255,0.8);--color2_150_bw:rgba(255,255,255,0.8);--color2_175_bw:rgba(255,255,255,0.8);;--font1:"Montserrat";--font2:"Raleway";--font3:"Helvetica Neue",sans-serif;--color1_rgb: 54,65,62;--color1_hsl: 164,9%,23%;--color1_hs: 164,9%;--color1_h: 164;--color1_s: 9%;--color1_l: 23%;--color1_25:#cdd0cf;--color1_50:#9ba09f;--color1_75:#68716e;--color1_125:#29312f;--color1_150:#1b211f;--color1_175:#0e1010;--color2_rgb: 93,94,96;--color2_hsl: 220,2%,37%;--color2_hs: 220,2%;--color2_h: 220;--color2_s: 2%;--color2_l: 37%;--color2_25:#d7d7d7;--color2_50:#aeafb0;--color2_75:#868688;--color2_125:#464748;--color2_150:#2f2f30;--color2_175:#171818;--color1_bw:rgba(255,255,255,0.8);--color1_25_bw:rgba(0,0,0,0.8);--color1_50_bw:rgba(255,255,255,0.8);--color1_75_bw:rgba(255,255,255,0.8);--color1_125_bw:rgba(255,255,255,0.8);--color1_150_bw:rgba(255,255,255,0.8);--color1_175_bw:rgba(255,255,255,0.8);--color2_bw:rgba(255,255,255,0.8);--color2_25_bw:rgba(0,0,0,0.8);--color2_50_bw:rgba(255,255,255,0.8);--color2_75_bw:rgba(255,255,255,0.8);--color2_125_bw:rgba(255,255,255,0.8);--color2_150_bw:rgba(255,255,255,0.8);--color2_175_bw:rgba(255,255,255,0.8);}#contentArea .koColor {color:#36413e;}ul.koCheckList li:before {background:#36413e;}.ko_Theme #website .btn-primary {background-color:var(--color2_175);border-color:var(--color2_175);}.ko_Theme #website .btn-outline-primary {color:var(--color2_175);border-color:var(--color2_175);}.ko_Theme #website .btn-outline-primary:hover {background-color:var(--color2_175);color:var(--color1_bw);border-color:var(--color2_175);}#website .page-item.active .page-link {background-color:#36413e;color:var(--color1_bw);border-color:var(--color2_175);}#contentArea a:not(.btn),#contentArea a.btn-link {color:var(--color2_175)}#website.kopageMenu a:not(.btn):not(.kopageMenuButton),#website.kopageMenu a.btn-link {color:var(--color2_175)}.ko_Theme #contentArea, .ko_Theme .koThemeDark #contentArea .whiteShadowContainer {color:var(--color2_175)}#contentArea h1, #contentArea h2, #contentArea h3,#contentArea h1 a, #contentArea h2 a, #contentArea h3 a, .koThemeDark #contentArea .whiteShadowContainer strong, .koThemeDark #contentArea .whiteShadowContainer h1, .koThemeDark #contentArea .whiteShadowContainer h2, .koThemeDark #contentArea .whiteShadowContainer h3{color: rgb(0, 0, 0);}#contentArea h4, #contentArea h5, #contentArea h6,#contentArea h4 a, #contentArea h5 a, #contentArea h6 a, .koThemeDark #contentArea .whiteShadowContainer strong, .koThemeDark #contentArea .whiteShadowContainer h4, .koThemeDark #contentArea .whiteShadowContainer h5, .koThemeDark #contentArea .whiteShadowContainer h6 {color: rgb(0, 0, 0);}.ko_Theme #website #footerContent {color: rgba(0, 0, 0, .5);}.ko_Theme #website #footerContent h1,.ko_Theme #website #footerContent h2,.ko_Theme #website #footerContent h3,.ko_Theme #website #footerContent h4,.ko_Theme #website #footerContent h5,.ko_Theme #website #footerContent h6 {color: rgba(0, 0, 0,1);}.ko_Theme #website, .ko_Theme #website p{font-family:var(--font2),sans-serif;}.ko_Theme #website a.btn, ...
# </head><body class=""> <div id="searchHolder">
# <form action="" method="get">
# <div>Search</div>
# <input autocomplete="off" class="form-control" id="searchInput" name="search" type="text"/>
# <button class="btn btn-color1" type="submit"><i class="fas fa-search"></i></button>
# <button class="btn btn-light" onclick="$('#searchHolder').removeClass('active')" type="reset"><i class="fas fa-times"></i></button>
# </form>
# </div>
# <div class="isLoading" id="websiteLoading"><svg class="spinner" viewbox="0 0 50 50"><circle class="path" cx="25" cy="25" fill="none" r="20" stroke-width="5"></circle></svg></div><div class="" id="website"><header id="header"><div id="headerMenu"><div class="container"><div class="logoHolder"><a class="logo" href="/"><h2><img alt="BookLooks.org" id="WebsiteLogo" src="data/files/openbooknew-1.png" style="border:0"/><span>BookLooks.org</span></h2></a></div><ul class="menuHolder topmenu"><li><a href="http://booklooks.org/"><span>Home</span></a></li>
# <li><a href="about"><span>About</span></a></li>
# <li><a href="blog"><span>Blog</span></a></li>
# <li><a href="ratings-system"><span>Ratings System</span></a></li>
# <li><a href="book-reports"><span>Book Reports</span></a></li>
# <li class="accent1"><a href="contact"><span>Contact</span></a></li>
# </ul></div></div></header><main class="WxEditableArea" id="contentArea"><div class="kelement" id="contentAreaElement"></div><section class="kedit keditDark keditTextShadow" data-background="data/files/25f13df5d4dea7a4da3345a357147e97.jpg" data-background-pos="2" data-bgcolor="--color2_175" data-padding="50-50" data-pcid="4007" id="kpg_4173360" style="background: url(data/files/25f13df5d4dea7a4da3345a357147e97.jpg) left top repeat;;background-color:var(--color2_175);padding-top:50px;padding-bottom:50px">
# <div class="container">
# <ol class="breadcrumb"><li class="breadcrumb-item"><a href="http://booklooks.org">Home</a></li><li class="breadcrumb-item active"><span class="keditable">Book Reports - A</span></li></ol>
# <h1 class="keditable">Book Reports - A</h1>
# </div>
# </section><section class="kedit" data-pcid="4016.3" id="kpg_447838" style=""><div class="container table-responsive">
# <table class="table koTable">
# <thead>
# <tr>
# <th class="keditable" scope="col"><a href="book-reports-1">#</a></th>
# <th class="keditable" scope="col"><a href="book-reports-a-1">A</a></th>
# <th class="keditable" scope="col"><a href="book-reports-b">B</a></th><th class="keditable"><a href="book-reports-c">C</a></th><th class="keditable"><a href="book-reports-d">D</a></th><th class="keditable"><a href="book-reports-e">E</a></th><th class="keditable"><a href="book-reports-f">F</a></th><th class="keditable"><a href="book-reports-g">G</a></th><th class="keditable"><a href="book-reports-h">H</a></th><th class="keditable"><a href="book-reports-i">I</a></th><th class="keditable"><a href="book-reports-j">J</a></th><th class="keditable"><a href="book-reports-k">K</a></th><th class="keditable"><a href="book-reports-l">L</a></th><th class="keditable"><a href="book-reports-m">M</a></th><th class="keditable"><a href="book-reports-n">N</a></th><th class="keditable"><a href="book-reports-o">O</a></th><th class="keditable"><a href="book-reports-p">P</a></th><th class="keditable"><a href="book-reports-q">Q</a></th><th class="keditable"><a href="book-reports-r">R</a></th><th class="keditable"><a href="book-reports-s">S</a></th><th class="keditable"><a href="book-reports-t">T</a></th><th class="keditable"><a href="book-reports-u">U</a></th><th class="keditable"><a href="book-reports-v">V</a></th><th class="keditable"><a href="book-reports-w">W</a></th><th class="keditable"><a href="book-reports-x">X</a></th><th class="keditable"><a href="book-reports-y">Y</a></th><th class="keditable"><a href="book-reports-z">Z</a></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# </div></section>
# <section class="kedit" id="kpg_9440541" style=""><div class="container"><h2 class="keditable mb-5">Content Advisory</h2><div class="keditable"><span style="color: rgb(0, 0, 0);">Be advised that there may be explicit material in our book reports that is inappropriate for children. It is only included for completeness so that parents seeking to inform themselves may do so with all the available information needed to make informed decisions.</span></div></div></section><section class="kedit" data-pcid="4016.3" id="kpg_180266" style="">
# <div class="container table-responsive">
# <table class="table koTable">
# <thead>
# <tr>
# <th class="keditable" scope="col">Title</th>
# <th class="keditable" scope="col">Author</th><th class="keditable">Rating       </th><th class="keditable"> Slick Sheet</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/A is for activist.pdf" target="_blank">A is for Activist</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Innosanto Nagara</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/An Abc of equality.pdf" target="_blank">An ABC of Equality</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Chana Ginelle Ewing</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Ablaze With Color.pdf" target="_blank">Ablaze with Color: A Story of Painter Alma Thomas </a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Jeanne Walker Harvey</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part.pdf" target="_blank">The Absolutely True Diary of a Part-Time Indian</a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Sherman Alexie</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Ace Voices.pdf" target="_blank">Ace Voices</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Eris Young</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Ada twist scientist.pdf" target="_blank">Ada Twist, Scientist</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Andrea Beaty</td><td class="keditable">0</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Adjustment day.pdf" target="_blank">Adjustment Day</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Chuck Palahniuk</td><td class="keditable">4</td><td class="keditable"><a href="data/files/Book Looks Reports/A/Adjustment Day slick sheet.pdf" target="_blank">here</a></td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Advocate for Yourself.pdf" target="_blank">Advocating for Yourself</a><a href="data/files/Book Looks Reports/A/The Absolutely True Diary of a Part Time Indian.pdf" target="_blank"><br/></a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Abby Colich</td><td class="keditable">0</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/After.pdf" target="_blank">After</a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Amy Efaw</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Al Capone does my shirts.pdf" target="_blank">Al Capone Does My Shirts</a><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank"><br/></a></td><td class="keditable">Gennifer Choldenko</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/All American Boys.pdf" target="_blank">All American Boys</a></td><td class="keditable">Jason Reynolds and Brendan Kiely</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/All Because You Matter.pdf" target="_blank">All Because You Matter</a></td><td class="keditable">Tami Charles</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/All Boys Arent Blue.pdf" target="_blank">All Boys Aren't Blue</a></td><td class="keditable">George M. Johnson</td><td class="keditable">4</td><td class="keditable"><a href="data/files/Book Looks Reports/A/All Boys Arent Blue Slick Sheet.pdf" target="_blank">here</a></td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/All The Bright Places.pdf" target="_blank">All the Bright Places</a></td><td class="keditable">Jennifer Niven</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/All the Things we do in the dark.pdf" target="_blank">All the Things We Do in the Dark</a></td><td class="keditable">Saundra Mitchell</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/All Your Perfects.pdf" target="_blank">All Your Perfects</a></td><td class="keditable">Colleen Hoover</td><td class="keditable">4</td><td class="keditable"><a href="data/files/Book Looks Reports/A/All your perfects slick sheet.pdf" target="_blank">here</a></td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Allegedly.pdf" target="_blank">Allegedly</a></td><td class="keditable">Tiffany Jackson</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Alma and How she got her name.pdf" target="_blank">Alma and How She Got Her Name</a></td><td class="keditable">Juana Martinez-Neal</td><td class="keditable">0</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Almost perfect.pdf" target="_blank">Almost Perfect</a></td><td class="keditable">Brian Katcher</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Alt Ed.pdf" target="_blank">Alt Ed</a></td><td class="keditable">Catherine Atkins</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/America.pdf" target="_blank">America</a></td><td class="keditable">E.R. Frank</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/An Ordinary Day.pdf" target="_blank">An Ordinary Day</a></td><td class="keditable">Elana K. Arnold</td><td class="keditable">0</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Anatomy of a Boyfriend.pdf" target="_blank">Anatomy of a Boyfriend</a></td><td class="keditable">Daria Snadowsky</td><td class="keditable">4</td><td class="keditable"><a href="data/files/Book Looks Reports/A/Anatomy of a Boyfriend slick sheet.pdf" target="_blank">here</a></td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Anatomy of a single Girl.pdf" target="_blank">Anatomy of a Single Girl</a></td><td class="keditable">Daria Snadowsky</td><td class="keditable">4</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/And they lived.pdf" target="_blank">And They Lived...</a></td><td class="keditable">Steven Salvatore</td><td class="keditable">4</td><td class="keditable"><a href="data/files/Book Looks Reports/A/And They Lived slick sheet.pdf" target="_blank">here</a></td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/ANGUS THONGS AND FULL FRONTAL SNOGGING CONFESSIONS OF GEORGIA NICOLSON.pdf" target="_blank">ANGUS, THONGS, AND FULL-FRONTAL SNOGGING</a></td><td class="keditable">Louise Rennison</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Anne Franks Diary graphic novel.pdf" target="_blank">Anne Frank's Diary: The Graphic Adaptation</a></td><td class="keditable">Ari Folman and David Polonsky</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Antiracist baby.pdf" target="_blank">Antiracist Baby</a></td><td class="keditable">Ibram X. Kendi</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Antonios card.pdf" target="_blank">Antonio's Card</a></td><td class="keditable">Rigoberto Gonzalez</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Are you a boy or are you a girl.pdf" target="_blank">Are You a Boy or Are You a Girl?</a></td><td class="keditable">Sarah Savage and Fox Fisher</td><td class="keditable">1</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Are You a Butterfly.pdf" target="_blank">Are You a Butterfly?</a></td><td class="keditable">Judy Allen and Tudor Humphries</td><td class="keditable">0</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Are you an ant.pdf" target="_blank">Are You an Ant?</a></td><td class="keditable">Judy Allen and Tudor Humphries</td><td class="keditable">0</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Are you my Mother A Comic Drama.pdf" target="_blank">Are You My Mother: A Comic Drama</a></td><td class="keditable">Alison Bechdel</td><td class="keditable">4</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Art of Drag.pdf" target="_blank">The Art of Drag</a><a href="data/files/Book Looks Reports/A/Are you my Mother A Comic Drama.pdf" target="_blank"><br/></a></td><td class="keditable">Jake Hall</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Art of Racing in the RAin.pdf" target="_blank">The Art of Racing in the Rain</a><a href="data/files/Book Looks Reports/A/Are you my Mother A Comic Drama.pdf" target="_blank"><br/></a></td><td class="keditable">Garth Stein</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Ask the Passengers.pdf" target="_blank">Ask the Passengers</a></td><td class="keditable">A.S. King</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Assassin and the Desert.pdf" target="_blank">The Assassin and the Desert</a></td><td class="keditable">Sarah J. Maas</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Assassin and the Empire.pdf" target="_blank">The Assassin and the Empire</a></td><td class="keditable">Sarah J. Maas</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Assassin and the Pirate Lord.pdf" target="_blank">The Assassin and the Pirate Lord</a></td><td class="keditable">Sarah J. Maas</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank">The Assassin's Blade</a></td><td class="keditable">Sarah J. Maas</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom.pdf" target="_blank">Assassination Classroom Volume 1</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom Volume 2.pdf" target="_blank">Assassination Classroom Volume 2</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination classroom volume 3.pdf" target="_blank">Assassination Classroom Volume 3</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom volume 4.pdf" target="_blank">Assassination Classroom Volume 4</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom Volume 5.pdf" target="_blank">Assassination Classroom Volume 5</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom volume 6.pdf" target="_blank">Assassination Classroom Volume 6</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom volume 7.pdf" target="_blank">Assassination Classroom Volume 7</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Assassination Classroom Volume 11.pdf" target="_blank">Assassination Classroom Volume 11</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Yusei Matsui</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Attack of the Black Rectangles.pdf" target="_blank">Attack of the Black Rectangles</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Amy Sarig King</td><td class="keditable">2</td><td class="keditable">...</td>
# </tr><tr>
# <td class="keditable"><a href="data/files/Book Looks Reports/A/Autoboyography.pdf" target="_blank">Autoboyography</a><a href="data/files/Book Looks Reports/A/The Assassins Blade.pdf" target="_blank"><br/></a></td><td class="keditable">Christina Lauren</td><td class="keditable">3</td><td class="keditable">...</td>
# </tr>
# </tbody>
# </table>
# </div>
# </section></main><footer id="footerContent"><section class="kedit keditFooter keditFooter2 p-0 keditDark kfilter1" data-background="data/files/n4pu0b.jpg" data-background-pos="1" data-bgcolor="--color1_75" data-pcid="5500.3" id="kedit_g743fvhm6" style="background: url(data/files/n4pu0b.jpg) no-repeat 50% 0px;background-size:cover;;background-color:var(--color1_75)"><div class="container keditFooterLine1">
# <div class="row">
# <div class="col-lg-8 d-flex flex-column align-self-center">
# <div class="kedit flex-fill" id="kpg_2371661" style=""><div class="keditable">Sign up for the BookLooks.org newsletter and have new book reports delivered right to your inbox<div><br/></div></div></div>
# </div>
# <div class="col-lg-4 align-self-center">
# <div class="kedit flex-fill" id="kpg_7585332" style=""><div class="keditable keditable-auto"><div id="custom-substack-embed"><style>.csw-theme-custom{
#             --csw-primary-color:#FFFFFF;
#             --csw-input-color:#000000;
#             --csw-text-color:#000000;
#             --csw-input-text-color:#FFFFFF;
#             }</style><form class="custom-substack-widget csw-theme-custom"><input placeholder="example@gmail.com" value=""/><button type="submit">Subscribe</button></form></div>
# <script>
#   window.CustomSubstackWidget = {
#     substackUrl: "booklooks.substack.com",
#     theme: "custom",
#     colors: {
#       primary: "#FFFFFF",
#       input: "#000000",
#       email: "#FFFFFF",
#       text: "#000000",
#     }
#   };
# </script>
# <script async="" src="https://substackapi.com/widget.js"></script>
# </div></div>
# </div>
# </div>
# </div>
# <div class="keditFooterLine2 keditFooterLineDarker">
# <div class="container text-center">
# <div class="kedit" id="kpg_4287473" style=""><div class="keditable keditFooterCopyright"><div><span style="font-family: var(--font2),sans-serif; font-size: 1.1rem; letter-spacing: -0.02em;">Copyright ©2022 BookLooks.org LLC, All Rights Reserved</span><br/></div></div></div>
# <div class="pt-0 kedit keditFooterApp" id="kpg_5528154" style=""><div class="footerHolder" id="keditFooterModule"><div class="social_fa social_bw social_bwh social_footer"><a href="http://twitter.com/@BookLooksOrg" target="_blank"><i class="fab fa-twitter fa-2x fa-fw"></i></a></div></div></div>
# </div>
# </div>
# <div class="keditLayer_header h-auto" data-color="var(--color1_175)" data-height="h-auto" data-style="6" style="fill:var(--color1_175);transform: scale(1,-1)"><svg height="100%" preserveaspectratio="none" viewbox="0 0 3112 100" width="100%">
# <defs></defs>
# <g transform="matrix(0.997611, 0, 0, 0.941303, -0.999626, -451.432556)">
# <g transform="matrix(1.05523,0,0,0.197876,-141.168,242.24)">
# <path d="M3091.86,1204.82C2087.93,1828.86 1103.28,1781.18 133.779,1204.82L133.779,1741.7L3091.86,1741.7L3091.86,1204.82Z" style="fill-rule:nonzero;"></path>
# </g>
# </g>
# </svg></div></section></footer></div><a href="javascript:void(null)" id="scrollToTop"><i class="fa fa-fw fa-arrow-up"></i></a>
# <script>
#
# 		window.onload =  function(){$('#websiteLoading').fadeOut(function(){$(this).remove()});$('body').attr('id','body');$(document).keyup(function(e){
#
# 				 // Escape and Control (ESC+CTRL) pressed, show login screen
# 			 	 if ((e.ctrlKey || e.metaKey) && (e.keyCode == 27/* || e.keyCode == 10*/)) {
# 					 window.location.href="index.php?open=login";
# 				 }
#
#
# 			});
#
#
# 		};
#
# 		</script><script>var magnificPopupInit=function(){$('a.lightbox').magnificPopup({type:'image',gallery:{enabled:true}});}</script><link href="https://cdnjs.cloudflare.com/ajax/libs/magnific-popup.js/1.1.0/magnific-popup.css" rel="stylesheet"/><script async="" onload="magnificPopupInit()" src="https://cdnjs.cloudflare.com/ajax/libs/magnific-popup.js/1.1.0/jquery.magnific-popup.js"></script>
# <script type="text/javascript"></script>
# <script defer="" src="https://cdn.jsdelivr.net/npm/instant.page@3.0.0/instantpage.min.js" type="module"></script><script>var menuCaption = "Select a page";</script><script async="" src="//booklooks.org//inc/live.js?" type="text/javascript"></script><link href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@5.12.0/css/all.min.css" rel="stylesheet"/><script src="https://cdn.jsdelivr.net/npm/bootstrap@4.4.1/dist/js/bootstrap.bundle.min.js" type="text/javascript"></script>
# <!-- AOS (Animate on Scroll) -->
# <link href="https://cdn.jsdelivr.net/npm/aos@2.3.4/dist/aos.css" rel="stylesheet"/>
# <script defer="" src="https://cdn.jsdelivr.net/npm/aos@2.3.4/dist/aos.min.js"></script><script>$(function(){AOS.init({offset:20,duration:800,easing:'ease',anchorPlacement:'top-top'});})</script><script>$(function(e){
# 		var a = 400,s = e('#scrollToTop');
# 		e(window).scroll(function(){
# 		e(this).scrollTop() > a ? s.addClass('active') : s.removeClass('active')}), s.on('click', function(a) {s.removeClass('active');e('body,html').animate({scrollTop: 0})
# 	})})</script><script type="text/javascript">$(function(){var dataText="supermode=stats&page=/book-reports-a-1&referrer=";$.ajax({type: "POST",url: "index.php",data: dataText,success: function(data) {}});});</script><script id="jsMenusSetup" type="text/javascript">window.addEventListener('load',function(){ddlevelsmenu.setup("1", "topbar","0","0");});</script>
# </body></html>
